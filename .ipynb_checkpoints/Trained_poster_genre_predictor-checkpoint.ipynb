# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def poster_model():
    poster_shape = (150, 150, 3)
    base_model = tf.keras.applications.ResNet50(include_top = False, weights = 'imagenet', input_shape = poster_shape)
    base_model.trainable = False
    input_layer = tf.keras.Input(poster_shape)
    x = tf.keras.applications.resnet.preprocess_input(input_layer)
    x = base_model(x, training = False)
    x = tfl.GlobalAveragePooling2D()(x)
    x = tfl.Dropout(0.2)(x)
    prediction_layer = tfl.Dense(19, 'sigmoid')
    outputs = prediction_layer(x) 
    model = tf.keras.Model(input_layer, outputs)
    return model

# %%
model = poster_model()
model.load_weights("model.h5")
s = ['Action', 'Adventure', 'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir', 'Horror', 'IMAX', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']

# %%
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# tf.__operators__.getitem_1 ( (None, 150, 150, 3)       0
# _________________________________________________________________
# tf.nn.bias_add_1 (TFOpLambda (None, 150, 150, 3)       0
# _________________________________________________________________
# resnet50 (Functional)        (None, 5, 5, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 19)                38931
# =================================================================
# Total params: 23,626,643
# Trainable params: 38,931
# Non-trainable params: 23,587,712
# _________________________________________________________________
# None

# %%
base_learning_rate = 0.01
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                  metrics=['accuracy'])

# %%
single_poster_check = tf.keras.preprocessing.image_dataset_from_directory(
        directory = 'single_test_image',  label_mode = None,
        color_mode='rgb', batch_size=32, image_size=(150,150) ,shuffle=True, seed=42)
# Out:
# Found 1 files belonging to 1 classes.

# %%
img = mpimg.imread('single_test_image/image/sample_image.jpg')
imgplot = plt.imshow(img)
plt.show()
single_pred = model.predict(single_poster_check)
for i in range(len(s)):
    if single_pred[0][i] > 0.5:
        print(s[i])
# Out:
# Adventure
# Comedy
# Sci-Fi
